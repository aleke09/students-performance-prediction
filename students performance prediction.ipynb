# %% [markdown]
# # important libraries

# %%
import sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # importing the dataset

# %%
# student = pd.read_csv('student-por.csv', sep=';')
# audit_risk = pd.read_csv('datasets/audit_risk.csv')
student_mat  = pd.read_csv('datasets/student-mat.csv', sep=';')
# student_por = pd.read_csv('datasets/student-por.csv')
# trial = pd.read_csv('datasets/trial.csv')
student_mat
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
student = student_mat['sex'].replace({'F':0, 'M':1})

# %%
student.sample(10)
# Out:
# 75     1
# 63     0
# 64     0
# 171    1
# 389    0
# 95     0
# 96     1
# 182    0
# 355    0
# 106    0
# Name: sex, dtype: int64

# %% [markdown]
# # selecting important featuers for training

# %%
df = student_mat[[ 'G1', 'G2', 'G3', 'failures', 'studytime', 'absences', 'age']]
y = df[['G3']]

# %%
df.sample(50)
# Out:
#      G1  G2  G3  failures  studytime  absences  age
# 112  10  13  13         1          2         6   16
# 40    7  10  11         1          2        25   16
# 96   11  15  15         0          1         2   16
# 221   6   5   0         1          3         0   17
# 311  14  12  13         0          2        20   19
# 287  13  12  12         0          3         6   17
# 134   9   0   0         0          2         0   15
# 292  12  12  13         1          2        12   18
# 114   9   9   9         0          2         8   15
# 189   8   9  10         0          2         4   17
# 78    8   8  10         3          1         2   17
# 345  13  13  14         0          3         7   18
# 132  10  13  12         0          1        12   17
# 212  12  13  14         0          2         0   16
# 371  14  12  12         0          1         3   18
# 213   6   7   8         1          2        15   18
# 230  13  13  14         0          2        14   17
# ...

# %% [markdown]
# # dividing the dataset into input variable and target

# %%
X = np.array(df.drop(['G3'], axis=1))
y = np.array(df['G3'])

# %% [markdown]
# # Training the model using Decission tree clasifier()

# %%
# clf = DecisionTreeClassifier()
# clf = sklearn.svm.SVC(kernel='linear')
clf = sklearn.neighbors.KNeighborsClassifier()
x_train, x_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size=.2)
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)
acc = clf.score(x_test, y_test)
score = accuracy_score(y_test, predictions)
print(acc)
print(predictions)
print(score)
# Out:
# 0.35443037974683544
# [12  6  9 13  9 12 11 15  0 11 14 11  0  8 12 18 11 10 13 15  6 10 16 10
#   9  6 15  8 11  6 16 12 12 16  8  0 13 17 10 13 15  8  8 11 10 10 10  9
#  10  7 10 10 11 13 11 16 14  0 11 12 10 11  8 15 10 14  9  9  0  5 13  8
#   8 11  8 10 16 10 14]
# 0.35443037974683544
